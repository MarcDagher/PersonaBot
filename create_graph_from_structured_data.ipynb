# %% [markdown]
# ## Initial Imports and Loading DotEnv Variables

# %%
import os
import re
from dotenv import load_dotenv
from pathlib import Path
import pandas as pd
pd.set_option('display.max_colwidth', 150)

# graph_functions.py has all the functions related to the graph. You can find it in this folder
from graph_functions import connect_to_database, create_node, create_relation, populate_graph

# %%
# Get environment variables
dotenv_path = Path('./.env')
load_dotenv(dotenv_path=dotenv_path)

uri = os.getenv('uri') # Path to graph database ex:"bolt://localhost:7687"
username = os.getenv('user_name') # graph database's username
password = os.getenv('password') # graph database's password

# %% [markdown]
# ## Helper Functions

# %%
## General helper functions that don't manipulate or connect to the graph

def evaluate_importance(importance, relation_root_label):
  if importance == "Not available": relation_name = f"low_{relation_root_label}"
  elif int(importance) >= 80: relation_name = f"strong_{relation_root_label}"
  elif int(importance) <= 40: relation_name = f"low_{relation_root_label}"
  else: relation_name = f"medium_{relation_root_label}"

  return relation_name


def get_personality_traits(coded_traits:str):
  personality_traits=['Social', 'Realistic', 'Investigative', 'Enterprising', 'Conventional', 'Artistic']
  decoded_traits = []
  for letter in coded_traits:
    if letter == "S": personality_trait = personality_traits[0]
    elif letter == "R": personality_trait = personality_traits[1]
    elif letter == "I": personality_trait = personality_traits[2]
    elif letter == "E": personality_trait = personality_traits[3]
    elif letter == "C": personality_trait = personality_traits[4]
    elif letter == "A": personality_trait = personality_traits[5]

    decoded_traits.append(personality_trait)
  
  return decoded_traits

def remove_white_spaces(text):
  text = re.sub(r"[ ]", "_", text)
  return text

# %% [markdown]
# ## Populate Graph Database

# %% [markdown]
# Manually populate graph using the functions found in graph_functions.py

# %%
# # Load Basic_Skills
# interests_df = pd.read_csv("../Datasets/ONet/combined csvs/Interests.csv")

# # Connect to Graph Database
# driver = connect_to_database(uri=uri, username=username, password=password)

# # Populate graph with Occupations, Personality_Trait and Create relation between Occupations and Personality_Trait
# for i in range(len(interests_df)):
#   occupation = interests_df.loc[i, 'Occupation']
#   job_zone = interests_df.loc[i, 'Job Zone']
#   personality_trait = interests_df.loc[i, 'Interest']
#   coded_personality_trait = interests_df.loc[i, 'Interest Code']

#   # Create node_1
#   create_node(driver=driver, label='Occupation', properties={'title': occupation, 'main_personality_trait': personality_trait})

#   traits = get_personality_traits(coded_traits=coded_personality_trait)
#   for trait in traits:
#     # Create node_2
#     create_node(driver=driver, label='Personality_Trait', properties={'title': trait})

#     # Create Relation
#     create_relation(
#       driver=driver,
#       n_label_1='Occupation', n_identifier_1={'title': occupation},
#       n_label_2='Personality_Trait', n_identifier_2={'title': trait},
#       relation_label='requires_personality_trait', relation_properties={'job_zone': job_zone}
#       )
# driver.close()

# %% [markdown]
# ### Prepeocess CSVs to make them compatible with the populate_graph function found in graph functions

# %% [markdown]
# Abilities

# %%
# Load abilities dataframe
df = pd.read_csv("../Datasets/ONet/combined csvs/Abilities.csv")

# Create an empty dataframe that will be filled according to the format needed by populate_graph()
formatted_abilities = pd.DataFrame(columns=['Node_1', 'Node_2', 'Relation'])

# Fill the new dataframe
for i in range(len(df)):
  level = df.loc[i, 'Level']
  job_zone = df.loc[i, 'Job Zone']
  occupation = remove_white_spaces(df.loc[i, 'Occupation'])
  ability = remove_white_spaces(df.loc[i, 'Ability'])
  category = remove_white_spaces(df.loc[i, 'Category'])

  importance = df.loc[i, 'Importance']
  relation_label = evaluate_importance(importance=importance, relation_root_label='need_for_ability')

  formatted_abilities.loc[i, "Node_1"] = str({'label': 'Occupation', 'properties': str({'title': occupation}), 'identifier': str({'title': occupation})})
  formatted_abilities.loc[i, "Node_2"] = str({'label': category, 'properties': str({'title': ability}), 'identifier': str({'title': ability})})
  formatted_abilities.loc[i, "Relation"] = str({'label': relation_label, 'properties': str({'importance': importance, 'level': level, 'job_zone': job_zone})})

formatted_abilities.to_csv("formatted_abilities.csv")

# %% [markdown]
# Basic_Skills

# %%
# Load Basic_Skills dataframe
df = pd.read_csv("../Datasets/ONet/combined csvs/Basic_Skills.csv")

# Create an empty dataframe that will be filled according to the format needed by populate_graph()
formatted_basic_skills = pd.DataFrame(columns=['Node_1', 'Node_2', 'Relation'])

# Fill the new dataframe
for i in range(len(df)):
  level = df.loc[i, 'Level']
  job_zone = df.loc[i, 'Job Zone']
  occupation = remove_white_spaces(df.loc[i, 'Occupation'])
  skill = remove_white_spaces(df.loc[i, 'Skill'])
  category = remove_white_spaces(df.loc[i, 'Category'])

  importance = df.loc[i, 'Importance']
  relation_label = evaluate_importance(importance=importance, relation_root_label='need_for_basic_skill')

  formatted_basic_skills.loc[i, "Node_1"] = str({'label': 'Occupation', 'properties': str({'title': occupation}), 'identifier': str({'title': occupation})})
  formatted_basic_skills.loc[i, "Node_2"] = str({'label': 'Basic_Skill', 'properties': str({'title': skill}), 'identifier': str({'title': skill})})
  formatted_basic_skills.loc[i, "Relation"] = str({'label': relation_label, 'properties': str({'importance': importance, 'level': level, 'job_zone': job_zone})})

formatted_basic_skills.to_csv("formatted_basic_skills.csv")

# %% [markdown]
# Cross-Functional Skills

# %%
# Load Cross-Functional Skills
df = pd.read_csv("../Datasets/ONet/combined csvs/Cross-Functional Skills.csv")

# Create an empty dataframe that will be filled according to the format needed by populate_graph()
formatted_cross_functional_skills = pd.DataFrame(columns=['Node_1', 'Node_2', 'Relation'])

# Fill new dataframe
for i in range(len(df)):
  level = df.loc[i, 'Level']
  job_zone = df.loc[i, 'Job Zone']
  occupation = remove_white_spaces(df.loc[i, 'Occupation'])
  skill = remove_white_spaces(df.loc[i, 'Skill'])
  category = remove_white_spaces(df.loc[i, 'Category'])

  importance = df.loc[i, 'Importance']
  relation_label = evaluate_importance(importance=importance, relation_root_label='need_for_cross_functional_skill')

  formatted_cross_functional_skills.loc[i, "Node_1"] = str({'label': 'Occupation', 'properties': str({'title': occupation}), 'identifier': str({'title': occupation})})
  formatted_cross_functional_skills.loc[i, "Node_2"] = str({'label': category, 'properties': str({'title': skill}), 'identifier': str({'title': skill})})
  formatted_cross_functional_skills.loc[i, "Relation"] = str({'label': relation_label, 'properties': str({'importance': importance, 'level': level, 'job_zone': job_zone})})

formatted_cross_functional_skills.to_csv("formatted_cross_functional_skills.csv")

# %% [markdown]
# Interests

# %%
# Load Interests
df = pd.read_csv("../Datasets/ONet/combined csvs/Interests.csv")

# Create an empty dataframe that will be filled according to the format needed by populate_graph()
formatted_interests = pd.DataFrame(columns=['Node_1', 'Node_2', 'Relation'])

index = -1
# Fill new dataframe
for i in range(len(df)):
  job_zone = df.loc[i, 'Job Zone']
  occupation = remove_white_spaces(df.loc[i, 'Occupation'])

  coded_personality_traits = df.loc[i, 'Interest Code']
  decoded_personality_traits = get_personality_traits(coded_traits=coded_personality_traits)

  for trait in decoded_personality_traits:
    index += 1
    print(f"{index}: {occupation} -> {trait}")
    formatted_interests.loc[index, "Node_1"] = str({'label': 'Occupation', 'properties': str({'title': occupation}), 'identifier': str({'title': occupation})})
    formatted_interests.loc[index, "Node_2"] = str({'label': 'Personality_Trait', 'properties': str({'title': trait}), 'identifier': str({'title': trait})})
    # formatted_interests.loc[index, "Relation"] = str({'label': 'need_for_personality_trait', 'properties': str({'job_zone': job_zone})})
    formatted_interests.loc[index, "Relation"] = str({'label': 'need_for_personality_trait', 'properties': str({})})


formatted_interests.to_csv("formatted_interests.csv")
# Out:
# 0: Amusement_and_Recreation_Attendants -> Conventional
# 1: Amusement_and_Recreation_Attendants -> Social
# 2: Amusement_and_Recreation_Attendants -> Realistic
# 3: Baristas -> Realistic
# 4: Baristas -> Conventional
# 5: Baristas -> Social
# 6: Dining_Room_and_Cafeteria_Attendants_and_Bartender_Helpers -> Realistic
# 7: Dining_Room_and_Cafeteria_Attendants_and_Bartender_Helpers -> Conventional
# 8: Dining_Room_and_Cafeteria_Attendants_and_Bartender_Helpers -> Social
# 9: Childcare_Workers -> Social
# 10: Childcare_Workers -> Conventional
# 11: Childcare_Workers -> Artistic
# 12: Home_Health_Aides -> Social
# 13: Home_Health_Aides -> Realistic
# 14: Home_Health_Aides -> Conventional
# 15: Hosts_and_Hostesses,_Restaurant,_Lounge,_and_Coffee_Shop -> Social
# 16: Hosts_and_Hostesses,_Restaurant,_Lounge,_and_Coffee_Shop -> Enterprising
# 17: Hosts_and_Hostesses,_Restaurant,_Lounge,_and_Coffee_Shop -> Conventional
# 18: Nannies -> Social
# 19: Nannies -> Artistic
# 20: Personal_Care_Aides -> Social
# 21: Personal_Care_Aides -> Conventional
# 22: Personal_Care_Aides -> Realistic
# 23: Physical_Therapist_Aides -> Social
# 24: Physical_Therapist_Aides -> Realistic
# 25: Physical_Therapist_Aides -> Conventional
# 26: Psychiatric_Aides -> Social
# 27: Psychiatric_Aides -> Investigative
# 28: Psychiatric_Aides -> Conventional
# 29: School_Bus_Monitors -> Social
# 30: School_Bus_Monitors -> Conventional
# 31: School_Bus_Monitors -> Realistic
# 32: Travel_Guides -> Social
# 33: Travel_Guides -> Enterprising
# 34: Travel_Guides -> Conventional
# 35: Ushers,_Lobby_Attendants,_and_Ticket_Takers -> Social
# 36: Ushers,_Lobby_Attendants,_and_Ticket_Takers -> Conventional
# 37: Ushers,_Lobby_Attendants,_and_Ticket_Takers -> Enterprising
# 38: Waiters_and_Waitresses -> Social
# 39: Waiters_and_Waitresses -> Conventional
# 40: Waiters_and_Waitresses -> Enterprising
# 41: Animal_Caretakers -> Realistic
# 42: Animal_Caretakers -> Social
# 43: Animal_Caretakers -> Conventional
# 44: Animal_Trainers -> Realistic
# 45: Animal_Trainers -> Social
# 46: Food_Servers,_Nonrestaurant -> Realistic
# 47: Food_Servers,_Nonrestaurant -> Social
# 48: Food_Servers,_Nonrestaurant -> Conventional
# 49: Funeral_Attendants -> Realistic
# 50: Funeral_Attendants -> Social
# 51: Funeral_Attendants -> Conventional
# 52: Hotel,_Motel,_and_Resort_Desk_Clerks -> Conventional
# 53: Hotel,_Motel,_and_Resort_Desk_Clerks -> Social
# 54: Hotel,_Motel,_and_Resort_Desk_Clerks -> Enterprising
# 55: Lifeguards,_Ski_Patrol,_and_Other_Recreational_Protective_Service_Workers -> Realistic
# 56: Lifeguards,_Ski_Patrol,_and_Other_Recreational_Protective_Service_Workers -> Social
# 57: Lifeguards,_Ski_Patrol,_and_Other_Recreational_Protective_Service_Workers -> Conventional
# 58: Medical_Secretaries_and_Administrative_Assistants -> Conventional
# 59: Medical_Secretaries_and_Administrative_Assistants -> Social
# 60: Passenger_Attendants -> Conventional
# 61: Passenger_Attendants -> Social
# 62: Passenger_Attendants -> Realistic
# 63: Shampooers -> Realistic
# 64: Shampooers -> Social
# 65: Shampooers -> Conventional
# 66: Acute_Care_Nurses -> Social
# 67: Acute_Care_Nurses -> Investigative
# 68: Acute_Care_Nurses -> Realistic
# 69: Career/Technical_Education_Teachers,_Postsecondary -> Social
# 70: Career/Technical_Education_Teachers,_Postsecondary -> Investigative
# 71: Concierges -> Social
# 72: Concierges -> Enterprising
# 73: Concierges -> Conventional
# 74: Dental_Hygienists -> Social
# 75: Dental_Hygienists -> Realistic
# 76: Dental_Hygienists -> Investigative
# 77: Dietetic_Technicians -> Social
# 78: Dietetic_Technicians -> Realistic
# 79: Dietetic_Technicians -> Conventional
# 80: Emergency_Medical_Technicians -> Social
# 81: Emergency_Medical_Technicians -> Realistic
# 82: Emergency_Medical_Technicians -> Investigative
# 83: Exercise_Trainers_and_Group_Fitness_Instructors -> Social
# 84: Exercise_Trainers_and_Group_Fitness_Instructors -> Realistic
# 85: Hearing_Aid_Specialists -> Social
# 86: Hearing_Aid_Specialists -> Investigative
# 87: Hearing_Aid_Specialists -> Conventional
# 88: Licensed_Practical_and_Licensed_Vocational_Nurses -> Social
# 89: Licensed_Practical_and_Licensed_Vocational_Nurses -> Realistic
# 90: Licensed_Practical_and_Licensed_Vocational_Nurses -> Conventional
# 91: Massage_Therapists -> Social
# 92: Massage_Therapists -> Realistic
# 93: Massage_Therapists -> Investigative
# 94: Nursing_Assistants -> Social
# 95: Nursing_Assistants -> Realistic
# 96: Nursing_Assistants -> Conventional
# 97: Occupational_Therapy_Aides -> Social
# 98: Occupational_Therapy_Aides -> Realistic
# 99: Occupational_Therapy_Aides -> Conventional
# 100: Occupational_Therapy_Assistants -> Social
# 101: Occupational_Therapy_Assistants -> Conventional
# 102: Occupational_Therapy_Assistants -> Realistic
# 103: Paramedics -> Social
# 104: Paramedics -> Realistic
# 105: Paramedics -> Investigative
# 106: Patient_Representatives -> Social
# 107: Patient_Representatives -> Investigative
# 108: Patient_Representatives -> Conventional
# 109: Physical_Therapist_Assistants -> Social
# 110: Physical_Therapist_Assistants -> Realistic
# 111: Physical_Therapist_Assistants -> Conventional
# 112: Preschool_Teachers,_Except_Special_Education -> Social
# 113: Preschool_Teachers,_Except_Special_Education -> Artistic
# 114: Psychiatric_Technicians -> Social
# 115: Psychiatric_Technicians -> Investigative
# 116: Residential_Advisors -> Social
# 117: Residential_Advisors -> Conventional
# 118: Residential_Advisors -> Enterprising
# 119: Respiratory_Therapists -> Social
# 120: Respiratory_Therapists -> Realistic
# 121: Respiratory_Therapists -> Investigative
# 122: Self-Enrichment_Teachers -> Social
# 123: Self-Enrichment_Teachers -> Artistic
# 124: Speech-Language_Pathology_Assistants -> Social
# 125: Speech-Language_Pathology_Assistants -> Conventional
# 126: Speech-Language_Pathology_Assistants -> Investigative
# 127: Teaching_Assistants,_Preschool,_Elementary,_Middle,_and_Secondary_School,_Except_Special_Education -> Social
# 128: Teaching_Assistants,_Preschool,_Elementary,_Middle,_and_Secondary_School,_Except_Special_Education -> Conventional
# 129: Teaching_Assistants,_Special_Education -> Social
# 130: Teaching_Assistants,_Special_Education -> Conventional
# 131: Tour_Guides_and_Escorts -> Social
# 132: Tour_Guides_and_Escorts -> Enterprising
# 133: Tutors -> Social
# 134: Adult_Basic_Education,_Adult_Secondary_Education,_and_English_as_a_Second_Language_Instructors -> Social
# 135: Career/Technical_Education_Teachers,_Middle_School -> Social
# 136: Career/Technical_Education_Teachers,_Secondary_School -> Social
# 137: Child,_Family,_and_School_Social_Workers -> Social
# 138: Coaches_and_Scouts -> Social
# 139: Coaches_and_Scouts -> Enterprising
# 140: Coaches_and_Scouts -> Realistic
# 141: Community_Health_Workers -> Social
# 142: Critical_Care_Nurses -> Social
# 143: Critical_Care_Nurses -> Investigative
# 144: Critical_Care_Nurses -> Realistic
# 145: Directors,_Religious_Activities_and_Education -> Social
# 146: Directors,_Religious_Activities_and_Education -> Enterprising
# 147: Education_and_Childcare_Administrators,_Preschool_and_Daycare -> Social
# 148: Education_and_Childcare_Administrators,_Preschool_and_Daycare -> Enterprising
# 149: Education_and_Childcare_Administrators,_Preschool_and_Daycare -> Conventional
# 150: Elementary_School_Teachers,_Except_Special_Education -> Social
# 151: Elementary_School_Teachers,_Except_Special_Education -> Artistic
# 152: Fitness_and_Wellness_Coordinators -> Social
# 153: Fitness_and_Wellness_Coordinators -> Enterprising
# 154: Health_Education_Specialists -> Social
# 155: Health_Education_Specialists -> Investigative
# 156: Health_Education_Specialists -> Conventional
# 157: Kindergarten_Teachers,_Except_Special_Education -> Social
# 158: Kindergarten_Teachers,_Except_Special_Education -> Artistic
# 159: Middle_School_Teachers,_Except_Special_and_Career/Technical_Education -> Social
# 160: Middle_School_Teachers,_Except_Special_and_Career/Technical_Education -> Artistic
# 161: Music_Therapists -> Social
# 162: Music_Therapists -> Artistic
# 163: Music_Therapists -> Investigative
# 164: Park_Naturalists -> Social
# 165: Park_Naturalists -> Investigative
# 166: Park_Naturalists -> Realistic
# 167: Probation_Officers_and_Correctional_Treatment_Specialists -> Social
# 168: Probation_Officers_and_Correctional_Treatment_Specialists -> Conventional
# 169: Probation_Officers_and_Correctional_Treatment_Specialists -> Enterprising
# 170: Recreation_Workers -> Social
# 171: Recreation_Workers -> Enterprising
# 172: Recreation_Workers -> Realistic
# 173: Recreational_Therapists -> Social
# 174: Recreational_Therapists -> Investigative
# 175: Registered_Nurses -> Social
# 176: Registered_Nurses -> Investigative
# 177: Registered_Nurses -> Conventional
# 178: Rehabilitation_Counselors -> Social
# 179: Secondary_School_Teachers,_Except_Special_and_Career/Technical_Education -> Social
# 180: Social_and_Human_Service_Assistants -> Social
# 181: Social_and_Human_Service_Assistants -> Conventional
# 182: Social_and_Human_Service_Assistants -> Enterprising
# 183: Special_Education_Teachers,_Elementary_School -> Social
# 184: Special_Education_Teachers,_Elementary_School -> Investigative
# 185: Special_Education_Teachers,_Kindergarten -> Social
# 186: Special_Education_Teachers,_Middle_School -> Social
# 187: Special_Education_Teachers,_Middle_School -> Investigative
# 188: Special_Education_Teachers,_Middle_School -> Artistic
# 189: Special_Education_Teachers,_Secondary_School -> Social
# 190: Special_Education_Teachers,_Secondary_School -> Investigative
# 191: Substitute_Teachers,_Short-Term -> Social
# 192: Substitute_Teachers,_Short-Term -> Conventional
# 193: Training_and_Development_Specialists -> Social
# 194: Training_and_Development_Specialists -> Conventional
# 195: Training_and_Development_Specialists -> Investigative
# 196: Acupuncturists -> Social
# 197: Acupuncturists -> Investigative
# 198: Acupuncturists -> Realistic
# 199: Adapted_Physical_Education_Specialists -> Social
# 200: Adapted_Physical_Education_Specialists -> Realistic
# 201: Agricultural_Sciences_Teachers,_Postsecondary -> Social
# 202: Agricultural_Sciences_Teachers,_Postsecondary -> Investigative
# 203: Anesthesiologist_Assistants -> Social
# 204: Anesthesiologist_Assistants -> Conventional
# 205: Anesthesiologist_Assistants -> Investigative
# 206: Anthropology_and_Archeology_Teachers,_Postsecondary -> Social
# 207: Anthropology_and_Archeology_Teachers,_Postsecondary -> Investigative
# 208: Architecture_Teachers,_Postsecondary -> Social
# 209: Architecture_Teachers,_Postsecondary -> Investigative
# 210: Architecture_Teachers,_Postsecondary -> Artistic
# 211: Area,_Ethnic,_and_Cultural_Studies_Teachers,_Postsecondary -> Social
# 212: Area,_Ethnic,_and_Cultural_Studies_Teachers,_Postsecondary -> Investigative
# 213: Art_Therapists -> Social
# 214: Art_Therapists -> Artistic
# 215: Art,_Drama,_and_Music_Teachers,_Postsecondary -> Social
# 216: Art,_Drama,_and_Music_Teachers,_Postsecondary -> Artistic
# 217: Athletic_Trainers -> Social
# 218: Athletic_Trainers -> Realistic
# 219: Athletic_Trainers -> Investigative
# 220: Atmospheric,_Earth,_Marine,_and_Space_Sciences_Teachers,_Postsecondary -> Social
# 221: Atmospheric,_Earth,_Marine,_and_Space_Sciences_Teachers,_Postsecondary -> Investigative
# 222: Biological_Science_Teachers,_Postsecondary -> Social
# 223: Biological_Science_Teachers,_Postsecondary -> Investigative
# 224: Business_Teachers,_Postsecondary -> Social
# 225: Business_Teachers,_Postsecondary -> Investigative
# 226: Chiropractors -> Social
# 227: Chiropractors -> Realistic
# 228: Chiropractors -> Investigative
# 229: Clergy -> Social
# 230: Clergy -> Enterprising
# 231: Clinical_and_Counseling_Psychologists -> Social
# 232: Clinical_and_Counseling_Psychologists -> Investigative
# 233: Clinical_Nurse_Specialists -> Social
# 234: Clinical_Nurse_Specialists -> Investigative
# 235: Clinical_Nurse_Specialists -> Conventional
# 236: Communications_Teachers,_Postsecondary -> Social
# 237: Communications_Teachers,_Postsecondary -> Investigative
# 238: Computer_Science_Teachers,_Postsecondary -> Social
# 239: Computer_Science_Teachers,_Postsecondary -> Investigative
# 240: Computer_Science_Teachers,_Postsecondary -> Conventional
# 241: Criminal_Justice_and_Law_Enforcement_Teachers,_Postsecondary -> Social
# 242: Criminal_Justice_and_Law_Enforcement_Teachers,_Postsecondary -> Investigative
# 243: Dietitians_and_Nutritionists -> Social
# 244: Dietitians_and_Nutritionists -> Investigative
# 245: Economics_Teachers,_Postsecondary -> Social
# 246: Economics_Teachers,_Postsecondary -> Investigative
# 247: Education_Administrators,_Kindergarten_through_Secondary -> Social
# 248: Education_Administrators,_Kindergarten_through_Secondary -> Enterprising
# 249: Education_Administrators,_Kindergarten_through_Secondary -> Conventional
# 250: Education_Administrators,_Postsecondary -> Social
# 251: Education_Administrators,_Postsecondary -> Enterprising
# 252: Education_Administrators,_Postsecondary -> Conventional
# 253: Education_Teachers,_Postsecondary -> Social
# 254: Education_Teachers,_Postsecondary -> Investigative
# 255: Educational,_Guidance,_and_Career_Counselors_and_Advisors -> Social
# 256: Educational,_Guidance,_and_Career_Counselors_and_Advisors -> Enterprising
# 257: Engineering_Teachers,_Postsecondary -> Social
# 258: Engineering_Teachers,_Postsecondary -> Investigative
# 259: Engineering_Teachers,_Postsecondary -> Realistic
# 260: English_Language_and_Literature_Teachers,_Postsecondary -> Social
# 261: English_Language_and_Literature_Teachers,_Postsecondary -> Investigative
# 262: English_Language_and_Literature_Teachers,_Postsecondary -> Artistic
# 263: Environmental_Science_Teachers,_Postsecondary -> Social
# 264: Environmental_Science_Teachers,_Postsecondary -> Investigative
# 265: Family_and_Consumer_Sciences_Teachers,_Postsecondary -> Social
# 266: Family_and_Consumer_Sciences_Teachers,_Postsecondary -> Investigative
# 267: Family_Medicine_Physicians -> Social
# 268: Family_Medicine_Physicians -> Investigative
# 269: Farm_and_Home_Management_Educators -> Social
# 270: Farm_and_Home_Management_Educators -> Investigative
# 271: Farm_and_Home_Management_Educators -> Realistic
# 272: Foreign_Language_and_Literature_Teachers,_Postsecondary -> Social
# 273: Foreign_Language_and_Literature_Teachers,_Postsecondary -> Investigative
# 274: Forestry_and_Conservation_Science_Teachers,_Postsecondary -> Social
# 275: Forestry_and_Conservation_Science_Teachers,_Postsecondary -> Investigative
# 276: Geography_Teachers,_Postsecondary -> Social
# 277: Geography_Teachers,_Postsecondary -> Investigative
# 278: Health_Specialties_Teachers,_Postsecondary -> Social
# 279: Health_Specialties_Teachers,_Postsecondary -> Investigative
# 280: Healthcare_Social_Workers -> Social
# 281: Healthcare_Social_Workers -> Investigative
# 282: History_Teachers,_Postsecondary -> Social
# 283: History_Teachers,_Postsecondary -> Investigative
# 284: Hospitalists -> Social
# 285: Hospitalists -> Investigative
# 286: Hospitalists -> Conventional
# 287: Instructional_Coordinators -> Social
# 288: Instructional_Coordinators -> Enterprising
# 289: Instructional_Coordinators -> Conventional
# 290: Law_Teachers,_Postsecondary -> Social
# 291: Law_Teachers,_Postsecondary -> Investigative
# 292: Library_Science_Teachers,_Postsecondary -> Social
# 293: Library_Science_Teachers,_Postsecondary -> Investigative
# 294: Low_Vision_Therapists,_Orientation_and_Mobility_Specialists,_and_Vision_Rehabilitation_Therapists -> Social
# 295: Low_Vision_Therapists,_Orientation_and_Mobility_Specialists,_and_Vision_Rehabilitation_Therapists -> Realistic
# 296: Low_Vision_Therapists,_Orientation_and_Mobility_Specialists,_and_Vision_Rehabilitation_Therapists -> Investigative
# 297: Marriage_and_Family_Therapists -> Social
# 298: Marriage_and_Family_Therapists -> Investigative
# 299: Mathematical_Science_Teachers,_Postsecondary -> Social
# 300: Mathematical_Science_Teachers,_Postsecondary -> Investigative
# 301: Mathematical_Science_Teachers,_Postsecondary -> Conventional
# 302: Mental_Health_and_Substance_Abuse_Social_Workers -> Social
# 303: Mental_Health_and_Substance_Abuse_Social_Workers -> Investigative
# 304: Mental_Health_Counselors -> Social
# 305: Mental_Health_Counselors -> Investigative
# 306: Midwives -> Social
# 307: Midwives -> Investigative
# 308: Midwives -> Realistic
# 309: Nurse_Anesthetists -> Social
# 310: Nurse_Anesthetists -> Realistic
# 311: Nurse_Anesthetists -> Investigative
# 312: Nurse_Midwives -> Social
# 313: Nurse_Midwives -> Investigative
# 314: Nursing_Instructors_and_Teachers,_Postsecondary -> Social
# 315: Nursing_Instructors_and_Teachers,_Postsecondary -> Investigative
# 316: Occupational_Therapists -> Social
# 317: Occupational_Therapists -> Investigative
# 318: Pediatricians,_General -> Social
# 319: Pediatricians,_General -> Investigative
# 320: Philosophy_and_Religion_Teachers,_Postsecondary -> Social
# 321: Philosophy_and_Religion_Teachers,_Postsecondary -> Investigative
# 322: Physical_Therapists -> Social
# 323: Physical_Therapists -> Investigative
# 324: Physical_Therapists -> Realistic
# 325: Physician_Assistants -> Social
# 326: Physician_Assistants -> Investigative
# 327: Physician_Assistants -> Conventional
# 328: Physics_Teachers,_Postsecondary -> Social
# 329: Physics_Teachers,_Postsecondary -> Investigative
# 330: Political_Science_Teachers,_Postsecondary -> Social
# 331: Political_Science_Teachers,_Postsecondary -> Investigative
# 332: Psychology_Teachers,_Postsecondary -> Social
# 333: Psychology_Teachers,_Postsecondary -> Investigative
# 334: Recreation_and_Fitness_Studies_Teachers,_Postsecondary -> Social
# 335: Recreation_and_Fitness_Studies_Teachers,_Postsecondary -> Investigative
# 336: School_Psychologists -> Social
# 337: School_Psychologists -> Investigative
# 338: School_Psychologists -> Conventional
# 339: Social_Work_Teachers,_Postsecondary -> Social
# 340: Social_Work_Teachers,_Postsecondary -> Investigative
# 341: Sociology_Teachers,_Postsecondary -> Social
# 342: Sociology_Teachers,_Postsecondary -> Investigative
# 343: Special_Education_Teachers,_Preschool -> Social
# 344: Special_Education_Teachers,_Preschool -> Artistic
# 345: Speech-Language_Pathologists -> Social
# 346: Speech-Language_Pathologists -> Investigative
# 347: Speech-Language_Pathologists -> Conventional
# 348: Substance_Abuse_and_Behavioral_Disorder_Counselors -> Social
# 349: Substance_Abuse_and_Behavioral_Disorder_Counselors -> Investigative
# 350: Substance_Abuse_and_Behavioral_Disorder_Counselors -> Conventional
# 351: Teaching_Assistants,_Postsecondary -> Social
# 352: Teaching_Assistants,_Postsecondary -> Conventional
# 353: Agricultural_Equipment_Operators -> Realistic
# 354: Agricultural_Equipment_Operators -> Conventional
# 355: Baristas -> Realistic
# 356: Baristas -> Conventional
# 357: Baristas -> Social
# 358: Cement_Masons_and_Concrete_Finishers -> Realistic
# 359: Cement_Masons_and_Concrete_Finishers -> Conventional
# 360: Conveyor_Operators_and_Tenders -> Realistic
# 361: Conveyor_Operators_and_Tenders -> Conventional
# 362: Cooks,_Fast_Food -> Realistic
# 363: Cooks,_Fast_Food -> Conventional
# 364: Cooks,_Fast_Food -> Enterprising
# 365: Cutters_and_Trimmers,_Hand -> Realistic
# 366: Cutters_and_Trimmers,_Hand -> Conventional
# 367: Derrick_Operators,_Oil_and_Gas -> Realistic
# 368: Derrick_Operators,_Oil_and_Gas -> Conventional
# 369: Dining_Room_and_Cafeteria_Attendants_and_Bartender_Helpers -> Realistic
# 370: Dining_Room_and_Cafeteria_Attendants_and_Bartender_Helpers -> Conventional
# 371: Dining_Room_and_Cafeteria_Attendants_and_Bartender_Helpers -> Social
# 372: Dishwashers -> Realistic
# 373: Dishwashers -> Conventional
# 374: Fallers -> Realistic
# 375: Fallers -> Conventional
# 376: Farmworkers_and_Laborers,_Crop,_Nursery,_and_Greenhouse -> Realistic
# 377: Farmworkers_and_Laborers,_Crop,_Nursery,_and_Greenhouse -> Conventional
# 378: Fast_Food_and_Counter_Workers -> Realistic
# 379: Fast_Food_and_Counter_Workers -> Conventional
# 380: Fast_Food_and_Counter_Workers -> Enterprising
# 381: Fishing_and_Hunting_Workers -> Realistic
# 382: Fishing_and_Hunting_Workers -> Conventional
# 383: Floor_Sanders_and_Finishers -> Realistic
# 384: Floor_Sanders_and_Finishers -> Conventional
# 385: Food_Preparation_Workers -> Realistic
# 386: Food_Preparation_Workers -> Conventional
# 387: Graders_and_Sorters,_Agricultural_Products -> Realistic
# 388: Graders_and_Sorters,_Agricultural_Products -> Conventional
# 389: Helpers--Painters,_Paperhangers,_Plasterers,_and_Stucco_Masons -> Realistic
# 390: Helpers--Painters,_Paperhangers,_Plasterers,_and_Stucco_Masons -> Conventional
# 391: Landscaping_and_Groundskeeping_Workers -> Realistic
# 392: Landscaping_and_Groundskeeping_Workers -> Conventional
# 393: Laundry_and_Dry-Cleaning_Workers -> Realistic
# 394: Laundry_and_Dry-Cleaning_Workers -> Conventional
# 395: Logging_Equipment_Operators -> Realistic
# 396: Logging_Equipment_Operators -> Conventional
# 397: Maids_and_Housekeeping_Cleaners -> Realistic
# 398: Maids_and_Housekeeping_Cleaners -> Conventional
# 399: Meat,_Poultry,_and_Fish_Cutters_and_Trimmers -> Realistic
# 400: Meat,_Poultry,_and_Fish_Cutters_and_Trimmers -> Conventional
# 401: Painting,_Coating,_and_Decorating_Workers -> Realistic
# 402: Painting,_Coating,_and_Decorating_Workers -> Artistic
# 403: Painting,_Coating,_and_Decorating_Workers -> Conventional
# 404: Plasterers_and_Stucco_Masons -> Realistic
# 405: Plasterers_and_Stucco_Masons -> Conventional
# 406: Pressers,_Textile,_Garment,_and_Related_Materials -> Realistic
# 407: Pressers,_Textile,_Garment,_and_Related_Materials -> Conventional
# 408: Rock_Splitters,_Quarry -> Realistic
# 409: Rock_Splitters,_Quarry -> Conventional
# 410: Roustabouts,_Oil_and_Gas -> Realistic
# 411: Roustabouts,_Oil_and_Gas -> Conventional
# 412: Septic_Tank_Servicers_and_Sewer_Pipe_Cleaners -> Realistic
# 413: Septic_Tank_Servicers_and_Sewer_Pipe_Cleaners -> Conventional
# 414: Sewing_Machine_Operators -> Realistic
# 415: Sewing_Machine_Operators -> Conventional
# 416: Adhesive_Bonding_Machine_Operators_and_Tenders -> Realistic
# 417: Adhesive_Bonding_Machine_Operators_and_Tenders -> Conventional
# 418: Agricultural_Inspectors -> Realistic
# 419: Agricultural_Inspectors -> Conventional
# 420: Agricultural_Inspectors -> Investigative
# 421: Aircraft_Service_Attendants -> Realistic
# 422: Aircraft_Service_Attendants -> Conventional
# 423: Aircraft_Structure,_Surfaces,_Rigging,_and_Systems_Assemblers -> Realistic
# 424: Aircraft_Structure,_Surfaces,_Rigging,_and_Systems_Assemblers -> Conventional
# 425: Ambulance_Drivers_and_Attendants,_Except_Emergency_Medical_Technicians -> Realistic
# 426: Ambulance_Drivers_and_Attendants,_Except_Emergency_Medical_Technicians -> Social
# 427: Ambulance_Drivers_and_Attendants,_Except_Emergency_Medical_Technicians -> Conventional
# 428: Animal_Breeders -> Realistic
# 429: Animal_Breeders -> Conventional
# 430: Animal_Caretakers -> Realistic
# 431: Animal_Caretakers -> Social
# 432: Animal_Caretakers -> Conventional
# 433: Animal_Control_Workers -> Realistic
# 434: Animal_Control_Workers -> Conventional
# 435: Animal_Control_Workers -> Investigative
# 436: Animal_Trainers -> Realistic
# 437: Animal_Trainers -> Social
# 438: Athletes_and_Sports_Competitors -> Realistic
# 439: Athletes_and_Sports_Competitors -> Enterprising
# 440: Athletes_and_Sports_Competitors -> Social
# 441: Automotive_and_Watercraft_Service_Attendants -> Realistic
# 442: Automotive_and_Watercraft_Service_Attendants -> Conventional
# 443: Automotive_Body_and_Related_Repairers -> Realistic
# 444: Automotive_Body_and_Related_Repairers -> Conventional
# 445: Automotive_Glass_Installers_and_Repairers -> Realistic
# 446: Automotive_Glass_Installers_and_Repairers -> Conventional
# 447: Baggage_Porters_and_Bellhops -> Realistic
# 448: Baggage_Porters_and_Bellhops -> Conventional
# 449: Baggage_Porters_and_Bellhops -> Social
# 450: Bakers -> Realistic
# 451: Bakers -> Conventional
# 452: Bartenders -> Realistic
# 453: Bartenders -> Conventional
# 454: Bartenders -> Enterprising
# 455: Bicycle_Repairers -> Realistic
# 456: Bicycle_Repairers -> Conventional
# 457: Biofuels_Processing_Technicians -> Realistic
# 458: Biofuels_Processing_Technicians -> Conventional
# 459: Biofuels_Processing_Technicians -> Investigative
# 460: Biomass_Plant_Technicians -> Realistic
# 461: Biomass_Plant_Technicians -> Conventional
# 462: Brickmasons_and_Blockmasons -> Realistic
# 463: Brickmasons_and_Blockmasons -> Conventional
# 464: Bridge_and_Lock_Tenders -> Realistic
# 465: Bridge_and_Lock_Tenders -> Conventional
# 466: Bus_Drivers,_School -> Realistic
# 467: Bus_Drivers,_School -> Conventional
# 468: Bus_Drivers,_School -> Social
# 469: Bus_Drivers,_Transit_and_Intercity -> Realistic
# 470: Bus_Drivers,_Transit_and_Intercity -> Conventional
# 471: Bus_Drivers,_Transit_and_Intercity -> Social
# 472: Butchers_and_Meat_Cutters -> Realistic
# 473: Butchers_and_Meat_Cutters -> Conventional
# 474: Cabinetmakers_and_Bench_Carpenters -> Realistic
# 475: Cabinetmakers_and_Bench_Carpenters -> Conventional
# 476: Carpenters -> Realistic
# 477: Carpenters -> Conventional
# 478: Carpet_Installers -> Realistic
# 479: Carpet_Installers -> Conventional
# 480: Chemical_Equipment_Operators_and_Tenders -> Realistic
# 481: Chemical_Equipment_Operators_and_Tenders -> Conventional
# 482: Chemical_Equipment_Operators_and_Tenders -> Investigative
# 483: Chemical_Plant_and_System_Operators -> Realistic
# 484: Chemical_Plant_and_System_Operators -> Conventional
# 485: Chemical_Plant_and_System_Operators -> Investigative
# 486: Cleaners_of_Vehicles_and_Equipment -> Realistic
# 487: Cleaners_of_Vehicles_and_Equipment -> Conventional
# 488: Cleaning,_Washing,_and_Metal_Pickling_Equipment_Operators_and_Tenders -> Realistic
# 489: Cleaning,_Washing,_and_Metal_Pickling_Equipment_Operators_and_Tenders -> Conventional
# 490: Coating,_Painting,_and_Spraying_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 491: Coating,_Painting,_and_Spraying_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 492: Coil_Winders,_Tapers,_and_Finishers -> Realistic
# 493: Coil_Winders,_Tapers,_and_Finishers -> Conventional
# 494: Coin,_Vending,_and_Amusement_Machine_Servicers_and_Repairers -> Realistic
# 495: Coin,_Vending,_and_Amusement_Machine_Servicers_and_Repairers -> Conventional
# 496: Computer_Numerically_Controlled_Tool_Operators -> Realistic
# 497: Computer_Numerically_Controlled_Tool_Operators -> Conventional
# 498: Construction_Laborers -> Realistic
# 499: Construction_Laborers -> Conventional
# 500: Continuous_Mining_Machine_Operators -> Realistic
# 501: Continuous_Mining_Machine_Operators -> Conventional
# 502: Cooks,_Institution_and_Cafeteria -> Realistic
# 503: Cooks,_Institution_and_Cafeteria -> Conventional
# 504: Cooks,_Restaurant -> Realistic
# 505: Cooks,_Restaurant -> Conventional
# 506: Cooks,_Restaurant -> Enterprising
# 507: Cooks,_Short_Order -> Realistic
# 508: Cooks,_Short_Order -> Conventional
# 509: Cooks,_Short_Order -> Enterprising
# 510: Cooling_and_Freezing_Equipment_Operators_and_Tenders -> Realistic
# 511: Cooling_and_Freezing_Equipment_Operators_and_Tenders -> Conventional
# 512: Correctional_Officers_and_Jailers -> Realistic
# 513: Correctional_Officers_and_Jailers -> Conventional
# 514: Correctional_Officers_and_Jailers -> Social
# 515: Crematory_Operators -> Realistic
# 516: Crematory_Operators -> Conventional
# 517: Crossing_Guards_and_Flaggers -> Realistic
# 518: Crossing_Guards_and_Flaggers -> Conventional
# 519: Crushing,_Grinding,_and_Polishing_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 520: Crushing,_Grinding,_and_Polishing_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 521: Cutting_and_Slicing_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 522: Cutting_and_Slicing_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 523: Cutting,_Punching,_and_Press_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 524: Cutting,_Punching,_and_Press_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 525: Dental_Laboratory_Technicians -> Realistic
# 526: Dental_Laboratory_Technicians -> Investigative
# 527: Dental_Laboratory_Technicians -> Conventional
# 528: Dredge_Operators -> Realistic
# 529: Dredge_Operators -> Conventional
# 530: Drilling_and_Boring_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 531: Drilling_and_Boring_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 532: Driver/Sales_Workers -> Realistic
# 533: Driver/Sales_Workers -> Conventional
# 534: Driver/Sales_Workers -> Enterprising
# 535: Drywall_and_Ceiling_Tile_Installers -> Realistic
# 536: Drywall_and_Ceiling_Tile_Installers -> Conventional
# 537: Earth_Drillers,_Except_Oil_and_Gas -> Realistic
# 538: Earth_Drillers,_Except_Oil_and_Gas -> Conventional
# 539: Earth_Drillers,_Except_Oil_and_Gas -> Investigative
# 540: Electrical_and_Electronic_Equipment_Assemblers -> Realistic
# 541: Electrical_and_Electronic_Equipment_Assemblers -> Conventional
# 542: Electrical_and_Electronic_Equipment_Assemblers -> Investigative
# 543: Electrical_Power-Line_Installers_and_Repairers -> Realistic
# 544: Electrical_Power-Line_Installers_and_Repairers -> Conventional
# 545: Electromechanical_Equipment_Assemblers -> Realistic
# 546: Electromechanical_Equipment_Assemblers -> Conventional
# 547: Electromechanical_Equipment_Assemblers -> Investigative
# 548: Endoscopy_Technicians -> Realistic
# 549: Endoscopy_Technicians -> Conventional
# 550: Endoscopy_Technicians -> Investigative
# 551: Engine_and_Other_Machine_Assemblers -> Realistic
# 552: Engine_and_Other_Machine_Assemblers -> Conventional
# 553: Etchers_and_Engravers -> Realistic
# 554: Etchers_and_Engravers -> Conventional
# 555: Etchers_and_Engravers -> Artistic
# 556: Excavating_and_Loading_Machine_and_Dragline_Operators,_Surface_Mining -> Realistic
# 557: Excavating_and_Loading_Machine_and_Dragline_Operators,_Surface_Mining -> Conventional
# 558: Explosives_Workers,_Ordnance_Handling_Experts,_and_Blasters -> Realistic
# 559: Explosives_Workers,_Ordnance_Handling_Experts,_and_Blasters -> Conventional
# 560: Explosives_Workers,_Ordnance_Handling_Experts,_and_Blasters -> Investigative
# 561: Extruding_and_Drawing_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 562: Extruding_and_Drawing_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 563: Extruding_and_Forming_Machine_Setters,_Operators,_and_Tenders,_Synthetic_and_Glass_Fibers -> Realistic
# 564: Extruding_and_Forming_Machine_Setters,_Operators,_and_Tenders,_Synthetic_and_Glass_Fibers -> Conventional
# 565: Extruding,_Forming,_Pressing,_and_Compacting_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 566: Extruding,_Forming,_Pressing,_and_Compacting_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 567: Farmworkers,_Farm,_Ranch,_and_Aquacultural_Animals -> Realistic
# 568: Fence_Erectors -> Realistic
# 569: Fence_Erectors -> Conventional
# 570: Fiberglass_Laminators_and_Fabricators -> Realistic
# 571: Fiberglass_Laminators_and_Fabricators -> Conventional
# 572: Floor_Layers,_Except_Carpet,_Wood,_and_Hard_Tiles -> Realistic
# 573: Floor_Layers,_Except_Carpet,_Wood,_and_Hard_Tiles -> Conventional
# 574: Floral_Designers -> Realistic
# 575: Floral_Designers -> Artistic
# 576: Floral_Designers -> Conventional
# 577: Food_and_Tobacco_Roasting,_Baking,_and_Drying_Machine_Operators_and_Tenders -> Realistic
# 578: Food_and_Tobacco_Roasting,_Baking,_and_Drying_Machine_Operators_and_Tenders -> Conventional
# 579: Food_Batchmakers -> Realistic
# 580: Food_Batchmakers -> Conventional
# 581: Food_Cooking_Machine_Operators_and_Tenders -> Realistic
# 582: Food_Cooking_Machine_Operators_and_Tenders -> Conventional
# 583: Food_Servers,_Nonrestaurant -> Realistic
# 584: Food_Servers,_Nonrestaurant -> Social
# 585: Food_Servers,_Nonrestaurant -> Conventional
# 586: Forest_and_Conservation_Workers -> Realistic
# 587: Forest_and_Conservation_Workers -> Conventional
# 588: Forging_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 589: Forging_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 590: Foundry_Mold_and_Coremakers -> Realistic
# 591: Foundry_Mold_and_Coremakers -> Conventional
# 592: Funeral_Attendants -> Realistic
# 593: Funeral_Attendants -> Social
# 594: Funeral_Attendants -> Conventional
# 595: Furnace,_Kiln,_Oven,_Drier,_and_Kettle_Operators_and_Tenders -> Realistic
# 596: Furnace,_Kiln,_Oven,_Drier,_and_Kettle_Operators_and_Tenders -> Conventional
# 597: Furniture_Finishers -> Realistic
# 598: Furniture_Finishers -> Conventional
# 599: Furniture_Finishers -> Artistic
# 600: Gas_Compressor_and_Gas_Pumping_Station_Operators -> Realistic
# 601: Gas_Compressor_and_Gas_Pumping_Station_Operators -> Conventional
# 602: Gas_Plant_Operators -> Realistic
# 603: Gas_Plant_Operators -> Conventional
# 604: Geothermal_Technicians -> Realistic
# 605: Geothermal_Technicians -> Conventional
# 606: Geothermal_Technicians -> Investigative
# 607: Glass_Blowers,_Molders,_Benders,_and_Finishers -> Realistic
# 608: Glass_Blowers,_Molders,_Benders,_and_Finishers -> Conventional
# 609: Glaziers -> Realistic
# 610: Glaziers -> Conventional
# 611: Grinding_and_Polishing_Workers,_Hand -> Realistic
# 612: Grinding_and_Polishing_Workers,_Hand -> Conventional
# 613: Grinding,_Lapping,_Polishing,_and_Buffing_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 614: Grinding,_Lapping,_Polishing,_and_Buffing_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 615: Heat_Treating_Equipment_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 616: Heat_Treating_Equipment_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 617: Heavy_and_Tractor-Trailer_Truck_Drivers -> Realistic
# 618: Heavy_and_Tractor-Trailer_Truck_Drivers -> Conventional
# 619: Helpers--Brickmasons,_Blockmasons,_Stonemasons,_and_Tile_and_Marble_Setters -> Realistic
# 620: Helpers--Brickmasons,_Blockmasons,_Stonemasons,_and_Tile_and_Marble_Setters -> Conventional
# 621: Helpers--Carpenters -> Realistic
# 622: Helpers--Carpenters -> Conventional
# 623: Helpers--Electricians -> Realistic
# 624: Helpers--Electricians -> Conventional
# 625: Helpers--Extraction_Workers -> Realistic
# 626: Helpers--Extraction_Workers -> Conventional
# 627: Helpers--Installation,_Maintenance,_and_Repair_Workers -> Realistic
# 628: Helpers--Installation,_Maintenance,_and_Repair_Workers -> Conventional
# 629: Helpers--Pipelayers,_Plumbers,_Pipefitters,_and_Steamfitters -> Realistic
# 630: Helpers--Pipelayers,_Plumbers,_Pipefitters,_and_Steamfitters -> Conventional
# 631: Helpers--Production_Workers -> Realistic
# 632: Helpers--Production_Workers -> Conventional
# 633: Helpers--Roofers -> Realistic
# 634: Helpers--Roofers -> Conventional
# 635: Highway_Maintenance_Workers -> Realistic
# 636: Highway_Maintenance_Workers -> Conventional
# 637: Hoist_and_Winch_Operators -> Realistic
# 638: Hoist_and_Winch_Operators -> Conventional
# 639: Home_Appliance_Repairers -> Realistic
# 640: Home_Appliance_Repairers -> Conventional
# 641: Industrial_Truck_and_Tractor_Operators -> Realistic
# 642: Industrial_Truck_and_Tractor_Operators -> Conventional
# 643: Inspectors,_Testers,_Sorters,_Samplers,_and_Weighers -> Realistic
# 644: Inspectors,_Testers,_Sorters,_Samplers,_and_Weighers -> Conventional
# 645: Inspectors,_Testers,_Sorters,_Samplers,_and_Weighers -> Investigative
# 646: Insulation_Workers,_Floor,_Ceiling,_and_Wall -> Realistic
# 647: Insulation_Workers,_Floor,_Ceiling,_and_Wall -> Conventional
# 648: Insulation_Workers,_Mechanical -> Realistic
# 649: Insulation_Workers,_Mechanical -> Conventional
# 650: Laborers_and_Freight,_Stock,_and_Material_Movers,_Hand -> Realistic
# 651: Laborers_and_Freight,_Stock,_and_Material_Movers,_Hand -> Conventional
# 652: Lathe_and_Turning_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 653: Lathe_and_Turning_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 654: Layout_Workers,_Metal_and_Plastic -> Realistic
# 655: Layout_Workers,_Metal_and_Plastic -> Conventional
# 656: Lifeguards,_Ski_Patrol,_and_Other_Recreational_Protective_Service_Workers -> Realistic
# 657: Lifeguards,_Ski_Patrol,_and_Other_Recreational_Protective_Service_Workers -> Social
# 658: Lifeguards,_Ski_Patrol,_and_Other_Recreational_Protective_Service_Workers -> Conventional
# 659: Light_Truck_Drivers -> Realistic
# 660: Light_Truck_Drivers -> Conventional
# 661: Loading_and_Moving_Machine_Operators,_Underground_Mining -> Realistic
# 662: Loading_and_Moving_Machine_Operators,_Underground_Mining -> Conventional
# 663: Locksmiths_and_Safe_Repairers -> Realistic
# 664: Locksmiths_and_Safe_Repairers -> Conventional
# 665: Locomotive_Engineers -> Realistic
# 666: Locomotive_Engineers -> Conventional
# 667: Locomotive_Engineers -> Investigative
# 668: Machine_Feeders_and_Offbearers -> Realistic
# 669: Machine_Feeders_and_Offbearers -> Conventional
# 670: Manicurists_and_Pedicurists -> Realistic
# 671: Manicurists_and_Pedicurists -> Conventional
# 672: Manufactured_Building_and_Mobile_Home_Installers -> Realistic
# 673: Manufactured_Building_and_Mobile_Home_Installers -> Conventional
# 674: Mechanical_Door_Repairers -> Realistic
# 675: Mechanical_Door_Repairers -> Conventional
# 676: Medical_Equipment_Preparers -> Realistic
# 677: Medical_Equipment_Preparers -> Conventional
# 678: Medical_Equipment_Preparers -> Investigative
# 679: Metal-Refining_Furnace_Operators_and_Tenders -> Realistic
# 680: Metal-Refining_Furnace_Operators_and_Tenders -> Conventional
# 681: Milling_and_Planing_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 682: Milling_and_Planing_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 683: Millwrights -> Realistic
# 684: Millwrights -> Conventional
# 685: Mixing_and_Blending_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 686: Mixing_and_Blending_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 687: Molders,_Shapers,_and_Casters,_Except_Metal_and_Plastic -> Realistic
# 688: Molders,_Shapers,_and_Casters,_Except_Metal_and_Plastic -> Conventional
# 689: Molding,_Coremaking,_and_Casting_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 690: Molding,_Coremaking,_and_Casting_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 691: Motion_Picture_Projectionists -> Realistic
# 692: Motion_Picture_Projectionists -> Conventional
# 693: Motorboat_Operators -> Realistic
# 694: Motorboat_Operators -> Conventional
# 695: Motorboat_Operators -> Enterprising
# 696: Multiple_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 697: Multiple_Machine_Tool_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 698: Non-Destructive_Testing_Specialists -> Realistic
# 699: Non-Destructive_Testing_Specialists -> Investigative
# 700: Non-Destructive_Testing_Specialists -> Conventional
# 701: Operating_Engineers_and_Other_Construction_Equipment_Operators -> Realistic
# 702: Operating_Engineers_and_Other_Construction_Equipment_Operators -> Conventional
# 703: Operating_Engineers_and_Other_Construction_Equipment_Operators -> Investigative
# 704: Ophthalmic_Laboratory_Technicians -> Realistic
# 705: Ophthalmic_Laboratory_Technicians -> Conventional
# 706: Orderlies -> Realistic
# 707: Orderlies -> Conventional
# 708: Orderlies -> Social
# 709: Outdoor_Power_Equipment_and_Other_Small_Engine_Mechanics -> Realistic
# 710: Outdoor_Power_Equipment_and_Other_Small_Engine_Mechanics -> Conventional
# 711: Packaging_and_Filling_Machine_Operators_and_Tenders -> Realistic
# 712: Packaging_and_Filling_Machine_Operators_and_Tenders -> Conventional
# 713: Painters,_Construction_and_Maintenance -> Realistic
# 714: Painters,_Construction_and_Maintenance -> Conventional
# 715: Paper_Goods_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 716: Paper_Goods_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 717: Paperhangers -> Realistic
# 718: Paperhangers -> Conventional
# 719: Paperhangers -> Artistic
# 720: Parking_Attendants -> Realistic
# 721: Parking_Attendants -> Conventional
# 722: Parking_Enforcement_Workers -> Realistic
# 723: Parking_Enforcement_Workers -> Conventional
# 724: Paving,_Surfacing,_and_Tamping_Equipment_Operators -> Realistic
# 725: Paving,_Surfacing,_and_Tamping_Equipment_Operators -> Conventional
# 726: Pest_Control_Workers -> Realistic
# 727: Pest_Control_Workers -> Conventional
# 728: Pesticide_Handlers,_Sprayers,_and_Applicators,_Vegetation -> Realistic
# 729: Pesticide_Handlers,_Sprayers,_and_Applicators,_Vegetation -> Conventional
# 730: Petroleum_Pump_System_Operators,_Refinery_Operators,_and_Gaugers -> Realistic
# 731: Petroleum_Pump_System_Operators,_Refinery_Operators,_and_Gaugers -> Conventional
# 732: Photographic_Process_Workers_and_Processing_Machine_Operators -> Realistic
# 733: Photographic_Process_Workers_and_Processing_Machine_Operators -> Conventional
# 734: Photographic_Process_Workers_and_Processing_Machine_Operators -> Artistic
# 735: Pile_Driver_Operators -> Realistic
# 736: Pile_Driver_Operators -> Conventional
# 737: Pipelayers -> Realistic
# 738: Pipelayers -> Conventional
# 739: Plating_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 740: Plating_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 741: Pourers_and_Casters,_Metal -> Realistic
# 742: Pourers_and_Casters,_Metal -> Conventional
# 743: Power_Plant_Operators -> Realistic
# 744: Power_Plant_Operators -> Conventional
# 745: Print_Binding_and_Finishing_Workers -> Realistic
# 746: Print_Binding_and_Finishing_Workers -> Conventional
# 747: Pump_Operators,_Except_Wellhead_Pumpers -> Realistic
# 748: Pump_Operators,_Except_Wellhead_Pumpers -> Conventional
# 749: Rail_Car_Repairers -> Realistic
# 750: Rail_Car_Repairers -> Conventional
# 751: Rail_Yard_Engineers,_Dinkey_Operators,_and_Hostlers -> Realistic
# 752: Rail_Yard_Engineers,_Dinkey_Operators,_and_Hostlers -> Conventional
# 753: Rail-Track_Laying_and_Maintenance_Equipment_Operators -> Realistic
# 754: Rail-Track_Laying_and_Maintenance_Equipment_Operators -> Conventional
# 755: Railroad_Brake,_Signal,_and_Switch_Operators_and_Locomotive_Firers -> Realistic
# 756: Railroad_Brake,_Signal,_and_Switch_Operators_and_Locomotive_Firers -> Conventional
# 757: Railroad_Conductors_and_Yardmasters -> Realistic
# 758: Railroad_Conductors_and_Yardmasters -> Conventional
# 759: Railroad_Conductors_and_Yardmasters -> Enterprising
# 760: Recreational_Vehicle_Service_Technicians -> Realistic
# 761: Recreational_Vehicle_Service_Technicians -> Conventional
# 762: Recycling_and_Reclamation_Workers -> Realistic
# 763: Recycling_and_Reclamation_Workers -> Conventional
# 764: Refractory_Materials_Repairers,_Except_Brickmasons -> Realistic
# 765: Refractory_Materials_Repairers,_Except_Brickmasons -> Conventional
# 766: Refuse_and_Recyclable_Material_Collectors -> Realistic
# 767: Refuse_and_Recyclable_Material_Collectors -> Conventional
# 768: Reinforcing_Iron_and_Rebar_Workers -> Realistic
# 769: Reinforcing_Iron_and_Rebar_Workers -> Conventional
# 770: Riggers -> Realistic
# 771: Riggers -> Conventional
# 772: Rolling_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Realistic
# 773: Rolling_Machine_Setters,_Operators,_and_Tenders,_Metal_and_Plastic -> Conventional
# 774: Roof_Bolters,_Mining -> Realistic
# 775: Roof_Bolters,_Mining -> Conventional
# 776: Roofers -> Realistic
# 777: Roofers -> Conventional
# 778: Rotary_Drill_Operators,_Oil_and_Gas -> Realistic
# 779: Rotary_Drill_Operators,_Oil_and_Gas -> Conventional
# 780: Sailors_and_Marine_Oilers -> Realistic
# 781: Sailors_and_Marine_Oilers -> Conventional
# 782: Sawing_Machine_Setters,_Operators,_and_Tenders,_Wood -> Realistic
# 783: Sawing_Machine_Setters,_Operators,_and_Tenders,_Wood -> Conventional
# 784: Security_Guards -> Realistic
# 785: Security_Guards -> Conventional
# 786: Segmental_Pavers -> Realistic
# 787: Segmental_Pavers -> Conventional
# 788: Semiconductor_Processing_Technicians -> Realistic
# 789: Semiconductor_Processing_Technicians -> Conventional
# 790: Separating,_Filtering,_Clarifying,_Precipitating,_and_Still_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 791: Separating,_Filtering,_Clarifying,_Precipitating,_and_Still_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 792: Service_Unit_Operators,_Oil_and_Gas -> Realistic
# 793: Service_Unit_Operators,_Oil_and_Gas -> Conventional
# 794: Sewers,_Hand -> Realistic
# 795: Sewers,_Hand -> Conventional
# 796: Sewers,_Hand -> Artistic
# 797: Shampooers -> Realistic
# 798: Shampooers -> Social
# 799: Shampooers -> Conventional
# 800: Sheet_Metal_Workers -> Realistic
# 801: Sheet_Metal_Workers -> Conventional
# 802: Shoe_and_Leather_Workers_and_Repairers -> Realistic
# 803: Shoe_and_Leather_Workers_and_Repairers -> Artistic
# 804: Shoe_Machine_Operators_and_Tenders -> Realistic
# 805: Shoe_Machine_Operators_and_Tenders -> Conventional
# 806: Shuttle_Drivers_and_Chauffeurs -> Realistic
# 807: Shuttle_Drivers_and_Chauffeurs -> Conventional
# 808: Shuttle_Drivers_and_Chauffeurs -> Social
# 809: Slaughterers_and_Meat_Packers -> Realistic
# 810: Slaughterers_and_Meat_Packers -> Conventional
# 811: Solar_Photovoltaic_Installers -> Realistic
# 812: Solar_Photovoltaic_Installers -> Conventional
# 813: Stone_Cutters_and_Carvers,_Manufacturing -> Realistic
# 814: Stone_Cutters_and_Carvers,_Manufacturing -> Artistic
# 815: Stone_Cutters_and_Carvers,_Manufacturing -> Conventional
# 816: Structural_Iron_and_Steel_Workers -> Realistic
# 817: Structural_Iron_and_Steel_Workers -> Conventional
# 818: Subway_and_Streetcar_Operators -> Realistic
# 819: Subway_and_Streetcar_Operators -> Conventional
# 820: Tailors,_Dressmakers,_and_Custom_Sewers -> Realistic
# 821: Tailors,_Dressmakers,_and_Custom_Sewers -> Artistic
# 822: Tank_Car,_Truck,_and_Ship_Loaders -> Realistic
# 823: Tank_Car,_Truck,_and_Ship_Loaders -> Conventional
# 824: Tapers -> Realistic
# 825: Tapers -> Conventional
# 826: Taxi_Drivers -> Realistic
# 827: Taxi_Drivers -> Conventional
# 828: Team_Assemblers -> Realistic
# 829: Team_Assemblers -> Conventional
# 830: Team_Assemblers -> Enterprising
# 831: Telecommunications_Line_Installers_and_Repairers -> Realistic
# 832: Telecommunications_Line_Installers_and_Repairers -> Conventional
# 833: Terrazzo_Workers_and_Finishers -> Realistic
# 834: Terrazzo_Workers_and_Finishers -> Conventional
# 835: Textile_Bleaching_and_Dyeing_Machine_Operators_and_Tenders -> Realistic
# 836: Textile_Bleaching_and_Dyeing_Machine_Operators_and_Tenders -> Conventional
# 837: Textile_Cutting_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 838: Textile_Cutting_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 839: Textile_Knitting_and_Weaving_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 840: Textile_Knitting_and_Weaving_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 841: Textile_Winding,_Twisting,_and_Drawing_Out_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 842: Textile_Winding,_Twisting,_and_Drawing_Out_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 843: Tile_and_Stone_Setters -> Realistic
# 844: Tile_and_Stone_Setters -> Conventional
# 845: Timing_Device_Assemblers_and_Adjusters -> Realistic
# 846: Timing_Device_Assemblers_and_Adjusters -> Conventional
# 847: Tire_Builders -> Realistic
# 848: Tire_Builders -> Conventional
# 849: Tire_Repairers_and_Changers -> Realistic
# 850: Tire_Repairers_and_Changers -> Conventional
# 851: Tool_Grinders,_Filers,_and_Sharpeners -> Realistic
# 852: Tool_Grinders,_Filers,_and_Sharpeners -> Conventional
# 853: Transportation_Vehicle,_Equipment_and_Systems_Inspectors,_Except_Aviation -> Realistic
# 854: Transportation_Vehicle,_Equipment_and_Systems_Inspectors,_Except_Aviation -> Conventional
# 855: Transportation_Vehicle,_Equipment_and_Systems_Inspectors,_Except_Aviation -> Investigative
# 856: Tree_Trimmers_and_Pruners -> Realistic
# 857: Tree_Trimmers_and_Pruners -> Conventional
# 858: Upholsterers -> Realistic
# 859: Upholsterers -> Artistic
# 860: Upholsterers -> Conventional
# 861: Veterinary_Assistants_and_Laboratory_Animal_Caretakers -> Realistic
# 862: Veterinary_Assistants_and_Laboratory_Animal_Caretakers -> Investigative
# 863: Veterinary_Assistants_and_Laboratory_Animal_Caretakers -> Conventional
# 864: Weatherization_Installers_and_Technicians -> Realistic
# 865: Weatherization_Installers_and_Technicians -> Conventional
# 866: Welders,_Cutters,_Solderers,_and_Brazers -> Realistic
# 867: Welders,_Cutters,_Solderers,_and_Brazers -> Conventional
# 868: Welding,_Soldering,_and_Brazing_Machine_Setters,_Operators,_and_Tenders -> Realistic
# 869: Welding,_Soldering,_and_Brazing_Machine_Setters,_Operators,_and_Tenders -> Conventional
# 870: Wellhead_Pumpers -> Realistic
# 871: Wellhead_Pumpers -> Conventional
# 872: Woodworking_Machine_Setters,_Operators,_and_Tenders,_Except_Sawing -> Realistic
# 873: Woodworking_Machine_Setters,_Operators,_and_Tenders,_Except_Sawing -> Conventional
# ...
# 2405: Compensation,_Benefits,_and_Job_Analysis_Specialists -> Conventional
# 2406: Compensation,_Benefits,_and_Job_Analysis_Specialists -> Enterprising
# 2407: Compensation,_Benefits,_and_Job_Analysis_Specialists -> Investigative
# 2408: Compliance_Managers -> Conventional
# 2409: Compliance_Managers -> Enterprising
# 2410: Computer_and_Information_Systems_Managers -> Conventional
# 2411: Computer_and_Information_Systems_Managers -> Enterprising
# 2412: Computer_and_Information_Systems_Managers -> Investigative
# 2413: Computer_Network_Support_Specialists -> Conventional
# 2414: Computer_Network_Support_Specialists -> Investigative
# 2415: Computer_Network_Support_Specialists -> Realistic
# 2416: Computer_Programmers -> Conventional
# 2417: Computer_Programmers -> Investigative
# 2418: Cost_Estimators -> Conventional
# 2419: Cost_Estimators -> Enterprising
# 2420: Credit_Analysts -> Conventional
# 2421: Credit_Analysts -> Enterprising
# 2422: Credit_Analysts -> Investigative
# 2423: Credit_Counselors -> Conventional
# 2424: Credit_Counselors -> Social
# 2425: Credit_Counselors -> Enterprising
# 2426: Data_Warehousing_Specialists -> Conventional
# 2427: Data_Warehousing_Specialists -> Investigative
# 2428: Database_Administrators -> Conventional
# 2429: Database_Administrators -> Investigative
# 2430: Database_Architects -> Conventional
# 2431: Database_Architects -> Investigative
# 2432: Document_Management_Specialists -> Conventional
# 2433: Document_Management_Specialists -> Investigative
# 2434: Environmental_Compliance_Inspectors -> Conventional
# 2435: Environmental_Compliance_Inspectors -> Investigative
# 2436: Environmental_Compliance_Inspectors -> Realistic
# 2437: Financial_and_Investment_Analysts -> Conventional
# 2438: Financial_and_Investment_Analysts -> Enterprising
# 2439: Financial_and_Investment_Analysts -> Investigative
# 2440: Financial_Examiners -> Conventional
# 2441: Financial_Examiners -> Enterprising
# 2442: Financial_Examiners -> Investigative
# 2443: Financial_Risk_Specialists -> Conventional
# 2444: Financial_Risk_Specialists -> Investigative
# 2445: Financial_Risk_Specialists -> Enterprising
# 2446: Fraud_Examiners,_Investigators_and_Analysts -> Conventional
# 2447: Fraud_Examiners,_Investigators_and_Analysts -> Enterprising
# 2448: Fraud_Examiners,_Investigators_and_Analysts -> Investigative
# 2449: Geographic_Information_Systems_Technologists_and_Technicians -> Conventional
# 2450: Geographic_Information_Systems_Technologists_and_Technicians -> Investigative
# 2451: Geographic_Information_Systems_Technologists_and_Technicians -> Realistic
# 2452: Industrial_Engineers -> Conventional
# 2453: Industrial_Engineers -> Investigative
# 2454: Industrial_Engineers -> Realistic
# 2455: Information_Security_Analysts -> Conventional
# 2456: Information_Security_Analysts -> Investigative
# 2457: Information_Security_Engineers -> Conventional
# 2458: Information_Security_Engineers -> Investigative
# 2459: Information_Security_Engineers -> Realistic
# 2460: Insurance_Underwriters -> Conventional
# 2461: Insurance_Underwriters -> Enterprising
# 2462: Insurance_Underwriters -> Investigative
# 2463: Interpreters_and_Translators -> Conventional
# 2464: Interpreters_and_Translators -> Artistic
# 2465: Interpreters_and_Translators -> Social
# 2466: Loan_Officers -> Conventional
# 2467: Loan_Officers -> Enterprising
# 2468: Loan_Officers -> Social
# 2469: Logisticians -> Conventional
# 2470: Logisticians -> Enterprising
# 2471: Logisticians -> Investigative
# 2472: Logistics_Analysts -> Conventional
# 2473: Logistics_Analysts -> Enterprising
# 2474: Logistics_Analysts -> Investigative
# 2475: Logistics_Engineers -> Conventional
# 2476: Logistics_Engineers -> Investigative
# 2477: Logistics_Engineers -> Realistic
# 2478: Loss_Prevention_Managers -> Conventional
# 2479: Loss_Prevention_Managers -> Enterprising
# 2480: Management_Analysts -> Conventional
# 2481: Management_Analysts -> Investigative
# 2482: Management_Analysts -> Enterprising
# 2483: Network_and_Computer_Systems_Administrators -> Conventional
# 2484: Network_and_Computer_Systems_Administrators -> Realistic
# 2485: Network_and_Computer_Systems_Administrators -> Investigative
# 2486: Online_Merchants -> Conventional
# 2487: Online_Merchants -> Enterprising
# 2488: Proofreaders_and_Copy_Markers -> Conventional
# 2489: Proofreaders_and_Copy_Markers -> Artistic
# 2490: Purchasing_Agents,_Except_Wholesale,_Retail,_and_Farm_Products -> Conventional
# 2491: Purchasing_Agents,_Except_Wholesale,_Retail,_and_Farm_Products -> Enterprising
# 2492: Purchasing_Agents,_Except_Wholesale,_Retail,_and_Farm_Products -> Realistic
# 2493: Quality_Control_Systems_Managers -> Conventional
# 2494: Quality_Control_Systems_Managers -> Enterprising
# 2495: Quality_Control_Systems_Managers -> Investigative
# 2496: Radio_Frequency_Identification_Device_Specialists -> Conventional
# 2497: Radio_Frequency_Identification_Device_Specialists -> Realistic
# 2498: Radio_Frequency_Identification_Device_Specialists -> Investigative
# 2499: Regulatory_Affairs_Specialists -> Conventional
# 2500: Regulatory_Affairs_Specialists -> Enterprising
# 2501: Regulatory_Affairs_Specialists -> Investigative
# 2502: Security_Management_Specialists -> Conventional
# 2503: Security_Management_Specialists -> Investigative
# 2504: Security_Management_Specialists -> Realistic
# 2505: Statistical_Assistants -> Conventional
# 2506: Statistical_Assistants -> Investigative
# 2507: Surveyors -> Conventional
# 2508: Surveyors -> Realistic
# 2509: Surveyors -> Investigative
# 2510: Technical_Writers -> Conventional
# 2511: Technical_Writers -> Artistic
# 2512: Technical_Writers -> Investigative
# 2513: Transportation_Inspectors -> Conventional
# 2514: Transportation_Inspectors -> Realistic
# 2515: Web_Administrators -> Conventional
# 2516: Web_Administrators -> Investigative
# 2517: Web_Administrators -> Enterprising
# 2518: Administrative_Law_Judges,_Adjudicators,_and_Hearing_Officers -> Conventional
# 2519: Administrative_Law_Judges,_Adjudicators,_and_Hearing_Officers -> Enterprising
# 2520: Administrative_Law_Judges,_Adjudicators,_and_Hearing_Officers -> Investigative
# 2521: Archivists -> Conventional
# 2522: Archivists -> Investigative
# 2523: Curators -> Conventional
# 2524: Curators -> Enterprising
# 2525: Judicial_Law_Clerks -> Conventional
# 2526: Judicial_Law_Clerks -> Enterprising
# 2527: Judicial_Law_Clerks -> Investigative
# 2528: Librarians_and_Media_Collections_Specialists -> Conventional
# 2529: Librarians_and_Media_Collections_Specialists -> Social
# 2530: Librarians_and_Media_Collections_Specialists -> Investigative
# 2531: Anesthesiologist_Assistants -> Social
# 2532: Anesthesiologist_Assistants -> Conventional
# 2533: Anesthesiologist_Assistants -> Investigative
# 2534: Arbitrators,_Mediators,_and_Conciliators -> Enterprising
# 2535: Arbitrators,_Mediators,_and_Conciliators -> Conventional
# 2536: Arbitrators,_Mediators,_and_Conciliators -> Social
# 2537: Biostatisticians -> Investigative
# 2538: Biostatisticians -> Conventional
# 2539: Computer_and_Information_Research_Scientists -> Investigative
# 2540: Computer_and_Information_Research_Scientists -> Conventional
# 2541: Computer_and_Information_Research_Scientists -> Realistic
# 2542: Economists -> Investigative
# 2543: Economists -> Conventional
# 2544: Economists -> Enterprising
# 2545: Financial_Quantitative_Analysts -> Investigative
# 2546: Financial_Quantitative_Analysts -> Conventional
# 2547: Geneticists -> Investigative
# 2548: Geneticists -> Conventional
# 2549: Geneticists -> Realistic
# 2550: Investment_Fund_Managers -> Enterprising
# 2551: Investment_Fund_Managers -> Conventional
# 2552: Investment_Fund_Managers -> Investigative
# 2553: Lawyers -> Enterprising
# 2554: Lawyers -> Conventional
# 2555: Lawyers -> Investigative
# 2556: Mathematicians -> Investigative
# 2557: Mathematicians -> Conventional
# 2558: Operations_Research_Analysts -> Investigative
# 2559: Operations_Research_Analysts -> Conventional
# 2560: Radiologists -> Investigative
# 2561: Radiologists -> Conventional
# 2562: Radiologists -> Realistic
# 2563: Statisticians -> Investigative
# 2564: Statisticians -> Conventional
# 2565: Survey_Researchers -> Investigative
# 2566: Survey_Researchers -> Conventional
# 2567: Teaching_Assistants,_Postsecondary -> Social
# 2568: Teaching_Assistants,_Postsecondary -> Conventional
# 2569: Painting,_Coating,_and_Decorating_Workers -> Realistic
# 2570: Painting,_Coating,_and_Decorating_Workers -> Artistic
# 2571: Painting,_Coating,_and_Decorating_Workers -> Conventional
# 2572: Actors -> Artistic
# 2573: Actors -> Social
# 2574: Actors -> Enterprising
# 2575: Costume_Attendants -> Artistic
# 2576: Costume_Attendants -> Conventional
# 2577: Costume_Attendants -> Realistic
# 2578: Disc_Jockeys,_Except_Radio -> Artistic
# 2579: Disc_Jockeys,_Except_Radio -> Enterprising
# 2580: Disc_Jockeys,_Except_Radio -> Conventional
# 2581: Models -> Artistic
# 2582: Models -> Realistic
# 2583: Models -> Enterprising
# 2584: Floral_Designers -> Realistic
# 2585: Floral_Designers -> Artistic
# 2586: Floral_Designers -> Conventional
# 2587: Nannies -> Social
# 2588: Nannies -> Artistic
# 2589: Shoe_and_Leather_Workers_and_Repairers -> Realistic
# 2590: Shoe_and_Leather_Workers_and_Repairers -> Artistic
# 2591: Stone_Cutters_and_Carvers,_Manufacturing -> Realistic
# 2592: Stone_Cutters_and_Carvers,_Manufacturing -> Artistic
# 2593: Stone_Cutters_and_Carvers,_Manufacturing -> Conventional
# 2594: Tailors,_Dressmakers,_and_Custom_Sewers -> Realistic
# 2595: Tailors,_Dressmakers,_and_Custom_Sewers -> Artistic
# 2596: Upholsterers -> Realistic
# 2597: Upholsterers -> Artistic
# 2598: Upholsterers -> Conventional
# 2599: Childcare_Workers -> Social
# 2600: Childcare_Workers -> Conventional
# 2601: Childcare_Workers -> Artistic
# 2602: Etchers_and_Engravers -> Realistic
# 2603: Etchers_and_Engravers -> Conventional
# 2604: Etchers_and_Engravers -> Artistic
# 2605: Furniture_Finishers -> Realistic
# 2606: Furniture_Finishers -> Conventional
# 2607: Furniture_Finishers -> Artistic
# 2608: Paperhangers -> Realistic
# 2609: Paperhangers -> Conventional
# 2610: Paperhangers -> Artistic
# 2611: Photographic_Process_Workers_and_Processing_Machine_Operators -> Realistic
# 2612: Photographic_Process_Workers_and_Processing_Machine_Operators -> Conventional
# 2613: Photographic_Process_Workers_and_Processing_Machine_Operators -> Artistic
# 2614: Sewers,_Hand -> Realistic
# 2615: Sewers,_Hand -> Conventional
# 2616: Sewers,_Hand -> Artistic
# 2617: Camera_Operators,_Television,_Video,_and_Film -> Artistic
# 2618: Camera_Operators,_Television,_Video,_and_Film -> Realistic
# 2619: Camera_Operators,_Television,_Video,_and_Film -> Conventional
# 2620: Craft_Artists -> Artistic
# 2621: Craft_Artists -> Realistic
# 2622: Dancers -> Artistic
# 2623: Dancers -> Realistic
# 2624: Dancers -> Social
# 2625: Fashion_Designers -> Artistic
# 2626: Fashion_Designers -> Realistic
# 2627: Fashion_Designers -> Enterprising
# 2628: Fine_Artists,_Including_Painters,_Sculptors,_and_Illustrators -> Artistic
# 2629: Fine_Artists,_Including_Painters,_Sculptors,_and_Illustrators -> Realistic
# 2630: Makeup_Artists,_Theatrical_and_Performance -> Artistic
# 2631: Makeup_Artists,_Theatrical_and_Performance -> Realistic
# 2632: Merchandise_Displayers_and_Window_Trimmers -> Artistic
# 2633: Merchandise_Displayers_and_Window_Trimmers -> Realistic
# 2634: Merchandise_Displayers_and_Window_Trimmers -> Enterprising
# 2635: Desktop_Publishers -> Conventional
# 2636: Desktop_Publishers -> Artistic
# 2637: Fabric_and_Apparel_Patternmakers -> Realistic
# 2638: Fabric_and_Apparel_Patternmakers -> Artistic
# 2639: Fabric_and_Apparel_Patternmakers -> Conventional
# 2640: Jewelers_and_Precious_Stone_and_Metal_Workers -> Realistic
# 2641: Jewelers_and_Precious_Stone_and_Metal_Workers -> Artistic
# 2642: Jewelers_and_Precious_Stone_and_Metal_Workers -> Conventional
# 2643: Musical_Instrument_Repairers_and_Tuners -> Realistic
# 2644: Musical_Instrument_Repairers_and_Tuners -> Artistic
# 2645: Musical_Instrument_Repairers_and_Tuners -> Conventional
# 2646: Photographers -> Realistic
# 2647: Photographers -> Artistic
# 2648: Preschool_Teachers,_Except_Special_Education -> Social
# 2649: Preschool_Teachers,_Except_Special_Education -> Artistic
# 2650: Self-Enrichment_Teachers -> Social
# 2651: Self-Enrichment_Teachers -> Artistic
# 2652: Sound_Engineering_Technicians -> Realistic
# 2653: Sound_Engineering_Technicians -> Artistic
# 2654: Sound_Engineering_Technicians -> Conventional
# 2655: Architectural_and_Civil_Drafters -> Realistic
# 2656: Architectural_and_Civil_Drafters -> Conventional
# 2657: Architectural_and_Civil_Drafters -> Artistic
# 2658: Model_Makers,_Wood -> Realistic
# 2659: Model_Makers,_Wood -> Conventional
# 2660: Model_Makers,_Wood -> Artistic
# 2661: Patternmakers,_Metal_and_Plastic -> Realistic
# 2662: Patternmakers,_Metal_and_Plastic -> Conventional
# 2663: Patternmakers,_Metal_and_Plastic -> Artistic
# 2664: Patternmakers,_Wood -> Realistic
# 2665: Patternmakers,_Wood -> Conventional
# 2666: Patternmakers,_Wood -> Artistic
# 2667: Art_Directors -> Artistic
# 2668: Art_Directors -> Enterprising
# 2669: Broadcast_Announcers_and_Radio_Disc_Jockeys -> Artistic
# 2670: Broadcast_Announcers_and_Radio_Disc_Jockeys -> Enterprising
# 2671: Broadcast_Announcers_and_Radio_Disc_Jockeys -> Social
# 2672: Choreographers -> Artistic
# 2673: Choreographers -> Social
# 2674: Commercial_and_Industrial_Designers -> Artistic
# 2675: Commercial_and_Industrial_Designers -> Realistic
# 2676: Commercial_and_Industrial_Designers -> Investigative
# 2677: Editors -> Artistic
# 2678: Editors -> Conventional
# 2679: Editors -> Enterprising
# 2680: Film_and_Video_Editors -> Artistic
# 2681: Film_and_Video_Editors -> Conventional
# 2682: Graphic_Designers -> Artistic
# 2683: Interior_Designers -> Artistic
# 2684: Interior_Designers -> Realistic
# 2685: Music_Directors_and_Composers -> Artistic
# 2686: Music_Directors_and_Composers -> Enterprising
# 2687: Musicians_and_Singers -> Artistic
# 2688: Musicians_and_Singers -> Enterprising
# 2689: News_Analysts,_Reporters,_and_Journalists -> Artistic
# 2690: News_Analysts,_Reporters,_and_Journalists -> Investigative
# 2691: News_Analysts,_Reporters,_and_Journalists -> Enterprising
# 2692: Poets,_Lyricists_and_Creative_Writers -> Artistic
# 2693: Poets,_Lyricists_and_Creative_Writers -> Investigative
# 2694: Producers_and_Directors -> Artistic
# 2695: Producers_and_Directors -> Enterprising
# 2696: Special_Effects_Artists_and_Animators -> Artistic
# 2697: Special_Effects_Artists_and_Animators -> Realistic
# 2698: Video_Game_Designers -> Artistic
# 2699: Video_Game_Designers -> Investigative
# 2700: Video_Game_Designers -> Enterprising
# 2701: Writers_and_Authors -> Artistic
# 2702: Writers_and_Authors -> Enterprising
# 2703: Kindergarten_Teachers,_Except_Special_Education -> Social
# 2704: Kindergarten_Teachers,_Except_Special_Education -> Artistic
# 2705: Music_Therapists -> Social
# 2706: Music_Therapists -> Artistic
# 2707: Music_Therapists -> Investigative
# 2708: Talent_Directors -> Enterprising
# 2709: Talent_Directors -> Artistic
# 2710: Talent_Directors -> Social
# 2711: Web_and_Digital_Interface_Designers -> Investigative
# 2712: Web_and_Digital_Interface_Designers -> Artistic
# 2713: Web_and_Digital_Interface_Designers -> Conventional
# 2714: Set_and_Exhibit_Designers -> Artistic
# 2715: Architects,_Except_Landscape_and_Naval -> Realistic
# 2716: Architects,_Except_Landscape_and_Naval -> Artistic
# 2717: Architects,_Except_Landscape_and_Naval -> Investigative
# 2718: Art_Therapists -> Social
# 2719: Art_Therapists -> Artistic
# 2720: Art,_Drama,_and_Music_Teachers,_Postsecondary -> Social
# 2721: Art,_Drama,_and_Music_Teachers,_Postsecondary -> Artistic
# 2722: Political_Scientists -> Investigative
# 2723: Political_Scientists -> Artistic
# 2724: Special_Education_Teachers,_Preschool -> Social
# 2725: Special_Education_Teachers,_Preschool -> Artistic
# 2726: Architecture_Teachers,_Postsecondary -> Social
# 2727: Architecture_Teachers,_Postsecondary -> Investigative
# 2728: Architecture_Teachers,_Postsecondary -> Artistic
# 2729: English_Language_and_Literature_Teachers,_Postsecondary -> Social
# 2730: English_Language_and_Literature_Teachers,_Postsecondary -> Investigative
# 2731: English_Language_and_Literature_Teachers,_Postsecondary -> Artistic
# 2732: Sociologists -> Investigative
# 2733: Sociologists -> Social
# 2734: Sociologists -> Artistic

# %% [markdown]
# Knowledge

# %%
# Load Knowledge
df = pd.read_csv("../Datasets/ONet/combined csvs/Knowledge.csv")

# Create an empty dataframe that will be filled according to the format needed by populate_graph()
formatted_knowledge = pd.DataFrame(columns=['Node_1', 'Node_2', 'Relation'])

# Fill new dataframe
for i in range(len(df)):
  level = df.loc[i, 'Level']
  job_zone = df.loc[i, 'Job Zone']
  occupation = remove_white_spaces(df.loc[i, 'Occupation'])
  knowledge = remove_white_spaces(df.loc[i, 'Knowledge'])
  category = remove_white_spaces(df.loc[i, 'Category'])

  importance = df.loc[i, 'Importance']
  relation_label = evaluate_importance(importance=importance, relation_root_label='need_for_knowledge_in')

  formatted_knowledge.loc[i, "Node_1"] = str({'label': 'Occupation', 'properties': str({'title': occupation}), 'identifier': str({'title': occupation})})
  formatted_knowledge.loc[i, "Node_2"]=str({'label': 'Knowledge', 'properties': str({'title': knowledge, 'category': category}), 'identifier': str({'title': knowledge})})
  formatted_knowledge.loc[i, "Relation"] = str({'label': relation_label, 'properties': str({'importance': importance, 'level': level, 'job_zone': job_zone})})

formatted_knowledge.to_csv("formatted_knowledge.csv")

# %% [markdown]
# ### NOTE: Moving forward, all we need is a formatted csv and then we run:
#
# driver = connect_to_database(uri=uri, username=username, password=password)
#
# populate_graph(driver, test)   # where test is the dataset/csv file
#
# driver.close()

# %%
# Connect to graph and populate it
from graph_functions import connect_to_database, create_node, create_relation, populate_graph

driver = connect_to_database(uri=uri, username=username, password=password)

populate_graph(driver, formatted_interests)

driver.close()
